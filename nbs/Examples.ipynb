# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import PIL.Image
from pyimgy.image_crop import *
from pyimgy.utils import *

# %%
img = PIL.Image.open('../images/bedroom-with-border.jpg')

# %% [markdown]
# ### Image cropping

# %%
ImageCropper(img).show()

# %% [markdown]
# ### Image palette

# %%
show_image_palette(img, 16)
